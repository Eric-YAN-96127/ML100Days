# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    
    """
    請完成這個 Function 後往下執行
    """
    
    mse = MSE = sum((y-yp)**2)/ len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 226.936
# The Mean absolute error is 11.679

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Ans:
# 我選擇"Vehicle Collisions in NYC,2015-Present"Dataset作為作業2的參考資料。
# https://www.kaggle.com/nypd/vehicle-collisions
#
#
# Q1. 你選的這組資料為何重要
# A1. 分析針對市區的車輛碰撞統計，有助於理解常態肇事主因及釐清現存交通系統是否存在問題。
#
# Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# A2. 資料是由NYC OpenData所發布，資料內容由NYPD(New York Police Department)透過記錄每筆車輛肇事所蒐集。
#
# Q3. 蒐集而來的資料型態為何
# A3. 資料的型態為"日期、時間、肇事地區及地點、肇事地點經緯度、傷亡類型、車輛種類、肇事原因"等。
#
# Q4. 這組資料想解決的問題如何評估
# A4. 透過日期、時間可以評估出肇事頻繁的時間範圍，或許是為交通尖峰時段或特殊節慶時段；根據地點可以判斷何處常有肇事發生，可能是容易交通容易阻塞之區域；藉由肇事的車輛型態、傷亡類型、肇事原因等數據，可以分析出該地點是否存在交通系統錯誤，如道路或號誌設計不佳等。
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
# Q1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# A1. 我認為提升業績的定義為：尖峰時段的載客量及離峰時段的穩定載客頻率，如在上下班時段或特殊節慶時能否藉機衝高業績，以及在離峰時段時仍能保持一定的載客量。
#
# Q2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A2. 在此舉例三種可能影響之資料，市民每週搭乘計程車的次數、對於尖峰時段的收費量意願及對於預先叫車服務的使用意願；上述資料可藉由問卷蒐集或是透過相關企業的OpenData所提供。
#
# Q3. 蒐集而來的資料型態為何
# A3. 所蒐集之資料型態，如每週搭乘計程車的次數為實際統計數據，其中包含了市民習慣乘車時的時段；而後兩者皆為意願調查數據。
#
# Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# A4. 透過乘車次數及時段的資料，可以大致掌握市民的乘車習慣及時態分布，針對此分布來派遣合理的車隊數量；針對尖峰時段的收費量意願調查，可以瞭解消費者對於合理價格的範圍多寡，以此可做為特定時段的價格策略，以利提高乘車意願；最後藉由預先叫車服務的使用意願調查，藉機提倡在離峰時段的價格優惠策略，以此策略來穩定離峰時段的載客頻率。
